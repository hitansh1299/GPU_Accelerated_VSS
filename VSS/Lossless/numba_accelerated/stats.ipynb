# %%
from skimage import io
import matplotlib.pyplot as plt

# %%
IMAGE = io.imread('../../images.jpeg')

# %%
plt.imshow(IMAGE)

# %%
import share_creator

# %%
import share_creator
import share_combiner
share1, share2 = share_creator.generate_shares(IMAGE, verbose=False)

combined_share = share_combiner.combine_shares(share1, share2, verbose=False)
#show both share1 and share2
plt.subplot(1,3,1)
plt.imshow(share1)
plt.subplot(1,3,2)
plt.imshow(share2)
plt.subplot(1,3,3)
plt.imshow(combined_share)
# plt.show()
# Out:
# c:\Users\hitan\OneDrive\Desktop\MiniProjects\SemVII_Capstone\Lossless\numba_accelerated\share_combiner.py:54: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see https://numba.readthedocs.io/en/stable/user/parallel.html#diagnostics for help.
#
# File "share_combiner.py", line 46:
# @jit(nopython=True, cache=True, parallel=PARALLEL)
# def denoise_image(img: np.ndarray):
# ^
#
#   combined_share = np.dstack((denoise_image(combined_share[:,:,0]),
# c:\Users\hitan\OneDrive\Desktop\MiniProjects\SemVII_Capstone\Lossless\numba_accelerated\share_combiner.py:54: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see https://numba.readthedocs.io/en/stable/user/parallel.html#diagnostics for help.
#
# ...

# %%
import cv2
vidcap = cv2.VideoCapture('share1.mp4')
x, _ = vidcap.read()
print(x, _)
# Out:
# False None

# %% [markdown]
# ## Speed Test

# %%
# %timeit share_combiner.combine_shares(*share_creator.generate_shares(IMAGE, verbose=False), verbose=False)
# Out:
# 161 ms ± 14.7 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit
